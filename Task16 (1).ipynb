# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('ZF_Elec_Responses.xlsx')
df.head()
# Out:
#                 Timestamp    Full Name (3 names at least) Phone Number  \
# 0 2022-05-12 19:30:19.458           Mohamed Monir Mohamed  01210933802
# 1 2022-05-12 20:01:06.995        Mohammed Salah Aboshosha  01027463950
# 2 2022-05-12 20:15:51.354  mohamed salah fathy abdelhamid  01004257855
# 3 2022-05-12 20:17:26.297  Omar Saad Mohamed Saad Soliman  01149493914
# 4 2022-05-12 20:30:14.318            ماجد علاء السيد محمد  01013414668
#
#                           Email         Faculty - Department Academic Year  \
# 0      mohameddobea13@gmail.com       Electrical engineering      3rd year
# 1  mohamedaboshosha12@gmail.com     Engineering - Electrical      2nd year
# 2      medosalahmedo4@gmail.com  engengineering-mechatronics      3rd year
# 3          mingosos13@gmail.com                 Mechatronics      3rd year
# 4        Magedalaazsc@gmail.com    كلية الهندسة - أولى كهربا      2nd year
#
#   Date of birth                                   Facebook URL  \
# ...

# %%
df.shape
# Out:
# (90, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 17 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Timestamp                                            90 non-null     datetime64[ns]
#  1   Full Name (3 names at least)                         90 non-null     object
#  2   Phone Number                                         90 non-null     object
#  3   Email                                                90 non-null     object
#  4   Faculty - Department                                 90 non-null     object
#  5   Academic Year                                        90 non-null     object
#  6   Date of birth                                        90 non-null     datetime64[ns]
#  7   Facebook URL                                         90 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                               0
# Full Name (3 names at least)                            0
# Phone Number                                            0
# Email                                                   0
# Faculty - Department                                    0
# Academic Year                                           0
# Date of birth                                           0
# Facebook URL                                            0
# LinkedIn URL (optional)                                32
# What do you know about Z Fast Racing Team?              0
# How did you hear about us?                              0
# Do you have any volunteering experience?                0
# If yes, what is your volunteering experience?           0
# What do you know about electrical vehicle ?             7
# What do you know about competition we participate ?    17
# What do you seek to learn by joining Z Fast Team?       0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Timestamp                                              datetime64[ns]
# Full Name (3 names at least)                                   object
# Phone Number                                                   object
# Email                                                          object
# Faculty - Department                                           object
# Academic Year                                                  object
# Date of birth                                          datetime64[ns]
# Facebook URL                                                   object
# LinkedIn URL (optional)                                        object
# What do you know about Z Fast Racing Team?                     object
# How did you hear about us?                                     object
# Do you have any volunteering experience?                       object
# If yes, what is your volunteering experience?                  object
# ...

# %%
df.sample()
# Out:
#                  Timestamp Full Name (3 names at least) Phone Number  \
# 54 2022-05-16 18:34:16.372        Reem Elsayed Abdelaty  01226217597
#
#                  Email                          Faculty - Department  \
# 54  ereem912@gmail.com  Mechanical engineering of Zagazig university
#
#    Academic Year Date of birth                                 Facebook URL  \
# 54      1st year    2001-11-11  https://www.facebook.com/reem.elsayed.71216
#
#    LinkedIn URL (optional)         What do you know about Z Fast Racing Team?  \
# 54            I don't have  تيم بيعمل عربيات كهربائيه و بيدخل مسابقات كتير...
#
#    How did you hear about us? Do you have any volunteering experience?  \
# 54          Facebook, Friends                                      Yes
#
#         If yes, what is your volunteering experience?  \
# 54  اشتركت فى تيمين واحد كان وظيفته عمل 3d printer...
#
#           What do you know about electrical vehicle ?  \
# ...

# %%
###
#pip install googletrans

# %%
#from googletrans import Translator, constants
#from pprint import pprint
#translator = Translator()

# %%
df = df.rename(columns ={'Full Name (3 names at least)':'Full_Name', 'Faculty - Department': 'Faculty&Department','Date of birth':
                     'Birth_date' ,'LinkedIn URL (optional)':'LinkedIn_URL' ,'What do you know about Z Fast Racing Team?':
                      'ZFast_Racing_Team' ,'How did you hear about us?':'hear us' , 'Do you have any volunteering experience?'
                       :'volunteering_experience' , 'If yes, what is your volunteering experience?' :'your volunteering'
                        ,'What do you know about electrical vehicle ?':'electrical_vehicle' ,'What do you know about competition we participate ?'
                        :'competition' ,'What do you seek to learn by joining Z Fast Team?':'your seeking' ,'Any questions?':'questions'})

# %%
df.sample()
# Out:
#                  Timestamp            Full_Name Phone Number  \
# 39 2022-05-14 16:19:46.393  Mohamed Ahmed Gamal  01065123961
#
#                     Email   Faculty&Department Academic Year Birth_date  \
# 39  mhmdghyth17@gmail.com  Electrical Engineer      3rd year 2000-12-02
#
#                                          Facebook URL  \
# 39  https://www.facebook.com/profile.php?id=100012...
#
#                                        LinkedIn_URL  \
# 39  http://www.linkedin.com/in/mohamed-gamal-ghaith
#
#                                     ZFast_Racing_Team  \
# 39  It is a student activity for the College of En...
#
#                                   hear us volunteering_experience  \
# 39  Facebook, Friends, Faculty colleagues                     Yes
#
#         your volunteering                                 electrical_vehicle  \
# 39  Iam amember in  IEEE   They are cars that are operated by electric mo...
#
#                                           competition  \
# ...

# %%
df.isna().sum()
# Out:
# Timestamp                   0
# Full_Name                   0
# Phone Number                0
# Email                       0
# Faculty&Department          0
# Academic Year               0
# Birth_date                  0
# Facebook URL                0
# LinkedIn_URL               32
# ZFast_Racing_Team           0
# hear us                     0
# volunteering_experience     0
# your volunteering           0
# electrical_vehicle          7
# competition                17
# your seeking                0
# questions                  39
# dtype: int64

# %%
df['LinkedIn_URL']=df['LinkedIn_URL'].fillna('null')

# %%
df.isna().sum()
# Out:
# Timestamp                   0
# Full_Name                   0
# Phone Number                0
# Email                       0
# Faculty&Department          0
# Academic Year               0
# Birth_date                  0
# Facebook URL                0
# LinkedIn_URL                0
# ZFast_Racing_Team           0
# hear us                     0
# volunteering_experience     0
# your volunteering           0
# electrical_vehicle          7
# competition                17
# your seeking                0
# questions                  39
# dtype: int64

# %%
#people that didn't enter their linkedIn
df[df['LinkedIn_URL'] =='null']
# Out:
#                  Timestamp                              Full_Name  \
# 2  2022-05-12 20:15:51.354         mohamed salah fathy abdelhamid
# 4  2022-05-12 20:30:14.318                   ماجد علاء السيد محمد
# 7  2022-05-12 20:45:14.940                   احمد حسام محمد عطية
# 8  2022-05-12 20:54:13.586             ابراهيم محمد ابراهيم محمد
# 10 2022-05-12 21:05:05.543                   محمود احمد محمود حسن
# 11 2022-05-12 21:37:44.338                         محمد ايمن محمد
# 14 2022-05-12 22:03:32.238                         محمد جمال سليم
# 15 2022-05-12 22:30:36.746         Khalid walid mohammed alazouni
# 17 2022-05-12 22:46:16.815                       Omar Tarek Fawzy
# 18 2022-05-12 22:47:06.332       احمد عبد المجيد محمد محمد منصور
# 19 2022-05-12 23:37:01.280  Ahmed Reda Ebrahim Abdulrhman Tahoon
# 26 2022-05-13 09:25:57.114        Abdelkader Ahmed Ismail Mohamed
# 33 2022-05-14 00:11:50.290                 السيد حسني السيد احمد
# ...

# %%
df['electrical_vehicle'] =df['electrical_vehicle'].fillna('null')

# %%
df.isna().sum()
# Out:
# Timestamp                   0
# Full_Name                   0
# Phone Number                0
# Email                       0
# Faculty&Department          0
# ...

# %%
# And didn't enter their linkedIn
df_f[df_f['LinkedIn_URL']=='null']
# Out:
#                  Timestamp                        Full_Name  Phone Number  \
# 52 2022-05-16 16:12:21.662               محمد عصمت عبدالله    01012069129
# 67 2022-05-17 23:01:30.759             Ahmed shady elsayed    01030705013
# 68 2022-05-18 12:54:26.201  Ahmed yousry mohamed eldidamony   01020810742
# 83 2022-05-24 18:40:44.285                Mohamed Salah Eid  010222388938
#
#                           Email  \
# 52  mahmoudesmat20029@gmail.com
# 67      medoshady153@gmail.com
# 68     ahmeddidamony9@gmail.com
# 83     mohamedarqan75@gmail.com
#
#                                  Faculty&Department Academic Year Birth_date  \
# 52                            engineering-electrics      2nd year 2002-09-28
# 67             هندسه الزقازيق قسم ميكاترونكس lvl000      1st year 2003-05-20
# 68  Faculty Of Engineering _ Electrical Department       1st year 2002-08-18
# 83                           Electrical Engineering      4th year 2000-08-01
#
# ...

# %%
df['questions'] = df['questions'].fillna('null')

# %%
df[df['questions']!='null']
# Out:
#                  Timestamp                       Full_Name   Phone Number  \
# 0  2022-05-12 19:30:19.458           Mohamed Monir Mohamed    01210933802
# 1  2022-05-12 20:01:06.995        Mohammed Salah Aboshosha    01027463950
# 2  2022-05-12 20:15:51.354  mohamed salah fathy abdelhamid    01004257855
# 3  2022-05-12 20:17:26.297  Omar Saad Mohamed Saad Soliman    01149493914
# 4  2022-05-12 20:30:14.318            ماجد علاء السيد محمد    01013414668
# ..                     ...                             ...            ...
# 85 2022-05-24 22:04:39.898               Ahmed Atef Saleh     01280149017
# 86 2022-05-24 23:26:36.607                محمد السيد الربع    01285688383
# 87 2022-05-25 00:08:13.074   احمد عصام فاروق ابوالخير احمد    01146907098
# 88 2022-05-25 10:50:32.161        اياد محمد عبدالحليم محمد    01021463089
# 89 2022-05-25 20:58:33.757         Muhammad Samir Muhammad  +201096390741
#
#                            Email                   Faculty&Department  \
# ...

# %%
#people that have a question
df[df['questions'].str.len()>20]
# Out:
#                  Timestamp                         Full_Name   Phone Number  \
# 17 2022-05-12 22:46:16.815                  Omar Tarek Fawzy    01272000099
# 31 2022-05-13 20:01:08.383            Mohamed Hamed Mabrouk     01208172520
# 49 2022-05-15 23:10:52.555             Aya Khaled Goda Sanad    01122080979
# 51 2022-05-16 12:58:09.910                   على ياسر النادى    01069371764
# 59 2022-05-16 22:25:45.971             Peter abdelmaseh riad    01278535821
# 73 2022-05-20 18:02:38.857  Moustafa Salah Abdelrahman Ahmed    01552780084
# 81 2022-05-23 10:42:00.052                 Peter Reda Boshra    01220865859
# 85 2022-05-24 22:04:39.898                 Ahmed Atef Saleh     01280149017
# 89 2022-05-25 20:58:33.757           Muhammad Samir Muhammad  +201096390741
#
#                              Email  \
# 17        ana.tarekelgan@gmail.com
# 31  mohamedhamed1462001@gmail.com
# 49         ayakhaled7420@gmail.com
# 51       alielnady20002@gmail.com
# ...

# %%
# the most is in 2nd year and 3rd year
df['Academic Year'].value_counts()
# Out:
# 2nd year    36
# 3rd year    35
# 1st year    14
# 4th year     4
# 5th year     1
# Name: Academic Year, dtype: int64

# %%
labels=['2nd year','3rd year','1st year','4th year','5th year']
plt.pie(df['Academic Year'].value_counts() ,labels = labels)
plt.show()

# %%
#facebook is most popular.
df['hear us'].value_counts()
# Out:
# Facebook                                            25
# Facebook, Friends                                   22
# Facebook, Friends, Faculty colleagues               20
# Friends                                              8
# Faculty colleagues                                   8
# Facebook, Faculty colleagues                         4
# Facebook, Instagram, Friends, Faculty colleagues     2
# Friends, Faculty colleagues                          1
# Name: hear us, dtype: int64

# %%
labels=['facbook','facebook&friends','facebook&friends&faculty','faculty','friends','facebook&faculty',
        'Facebook&Instagram&Friends&Faculty colleagues','Friends&Faculty']
plt.pie(df['hear us'].value_counts() ,labels =labels)
plt.show()

# %%
# the most have volunteering experience
df['volunteering_experience'].value_counts()
# Out:
# Yes    52
# No     38
# Name: volunteering_experience, dtype: int64

# %%
# the most is between 2001 to 2003
# one entered wrong birth date ">2020"!!
df.hist(figsize=(25,7))
plt.show()

# %%
#the most is in electrical engineer 
df['Faculty&Department'].value_counts()
# Out:
# electrical engineering                              4
# Electrical Engineering                              3
# Engineering - Electrical                            3
# Mechatronics                                        3
# Engineering - Electrical                            2
#                                                    ..
# Faculty of engineering - Mechatronics               1
# Faculty of Engineering || Electrical Department     1
# Engineering electrical department                   1
# engineering (electrical)                            1
# Engineering - Electrical (2nd year)                 1
# Name: Faculty&Department, Length: 76, dtype: int64

# %%
df['Faculty&Department'].values
# Out:
# array(['Electrical engineering', 'Engineering - Electrical',
#        'engengineering-mechatronics', 'Mechatronics',
#        'كلية الهندسة - أولى كهربا',
#        'Faculty of Engineering ZU- Electrical Department ',
#        'الهندسه قسم كهرباء', 'engineering-electric',
#        'Electrical engineering ',
#        'Electrical department , faculty of engineering ', 'Electrical',
#        'Engineering - Electrical ', 'Engineering-prep',
#        'Faculty of electrical engineering', 'Engineering-Electrical',
#        'Mechatronics',
#        'Faculty of engineering - Electrical power and Machines ',
#        'CIC- mechatronics', 'Prep',
#        'Faculty of engineering _ Electrical department ',
#        'Engineering _ prep year', 'Engineering - Zagazig',
#        'Electrical Engineering ', 'Electric department ',
#        'engineering- electric department ',
#        'Faculty of engineering - prepatory',
#        'Air defence college/communication and electronics',
# ...

# %%
# the most is male
df['Full_Name'].values
# Out:
# array(['Mohamed Monir Mohamed', 'Mohammed Salah Aboshosha',
#        'mohamed salah fathy abdelhamid', 'Omar Saad Mohamed Saad Soliman',
#        'ماجد علاء السيد محمد', 'Mostafa Mohamed Ahmed ',
#        'محمد احمد محمد السيد', 'احمد حسام محمد عطية ',
#        'ابراهيم محمد ابراهيم محمد ', 'Mohamed salah mohamed',
#        'محمود احمد محمود حسن', 'محمد ايمن محمد', 'Ali Abdelzez Zaghlol',
#        'Mahmoud Ammar Abd Elaziz Hassan', 'محمد جمال سليم',
#        'Khalid walid mohammed alazouni', 'Mohamed Ali Ahmed',
#        'Omar Tarek Fawzy', 'احمد عبد المجيد محمد محمد منصور ',
#        'Ahmed Reda Ebrahim Abdulrhman Tahoon ', 'Mina Fayez Khalil',
#        'Mohamed ahmed abdull-haleam', 'Mahmoud Abdelnaby mohamed',
#        'Abdulrahman Omar Hassan ', 'اية رضا اليمانى ',
#        'Abdulrahman Amr Sleem', 'Abdelkader Ahmed Ismail Mohamed',
#        ' Hady hisham mahmoud ', 'Mohamed Ali Bayoumi ',
#        'Hesham Khaled Salah Mohamed', 'Menna Allah Mohamed Ibrahem',
# ...
